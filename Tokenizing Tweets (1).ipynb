# %%
# imports

import urllib.request
import string
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import RegexpTokenizer
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Temp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Temp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
df = pd.read_csv('LabeledTweets(2).csv')
df = df.filter(['Content'],axis=1)
df
# Out:
#                                                  Content
# 0      Breaking: An abortion pill will be made more w...
# 1      Rivian fell short of its 25,000-vehicle produc...
# 2      🎧  Listen: In today's episode of The Journal p...
# 3      Damar Hamlin‘s charitable toy drive has raised...
# 4      Federal prosecutors have charged two men in th...
# ...                                                  ...
# 64468  REI To Close Portland Store, Citing 'Safety Of...
# 64469  The House GOP Effort To Defund – Not Police, B...
# 64470  Post-Pandemic Burnout: 20% Of Nurses May Quit ...
# 64471  Transgender Athlete Barred from Australian Wom...
# 64472  Trump's Palm Beach Mansion Next To Mar-A-Lago ...
#
# [64473 rows x 1 columns]

# %%
wordList = []
for i,row in df.iterrows():
    tokens = word_tokenize(row['Content'].lower())
    wordList.extend(tokens)

# %%
len(wordList)
# Out:
# 1531669

# %%
wordMap = {}

# %%
for word in wordList:
    if word not in wordMap:
        wordMap[word] = 1
    else:
        wordMap[word] += 1

# %%
orderedMap = sorted(wordMap.items(), key = lambda x: x[1], reverse = True)

# %%
len(orderedMap)
# Out:
# 100653

# %%
orderedMap
# Out:
# [(':', 81481),
#  ('https', 53533),
#  ('the', 40277),
#  (',', 39915),
#  ('to', 32684),
#  ('.', 28566),
#  ('of', 22681),
#  ('in', 22192),
#  ('$', 20041),
#  ('a', 19648),
#  ('and', 15713),
#  ("'s", 14560),
#  ('%', 13080),
#  ('for', 11557),
#  ('on', 11069),
#  ('is', 9731),
#  ('-', 8406),
#  ('’', 7878),
#  ('at', 6634),
#  ('as', 6482),
#  ('@', 6435),
#  ('s', 6262),
#  ('that', 6027),
#  ('with', 5976),
#  (')', 5823),
#  ('from', 5817),
#  ('(', 5793),
#  ('us', 5715),
#  ('by', 5555),
#  ('are', 5117),
#  ('fed', 5002),
#  ('it', 4824),
#  ('will', 4620),
#  ('has', 4408),
#  ('says', 4230),
#  ('more', 3970),
#  ('be', 3854),
#  ('after', 3809),
#  ("''", 3632),
#  ('u.s.', 3623),
#  ('bank', 3592),
#  ('china', 3562),
#  ('we', 3470),
#  ('new', 3435),
#  ('``', 3384),
#  ('previous', 3321),
#  ('its', 3320),
#  ("'", 3216),
#  (';', 3212),
#  ('actual', 3170),
#  ('have', 3153),
#  ('inflation', 3068),
#  ('this', 2959),
#  ('an', 2910),
#  ('said', 2874),
# ...

# %%
wordList = list(wordMap.keys())

# %%
wordList = [word.lower() for word in wordList if (word not in stopwords.words('english')) and (word not in string.punctuation)]

# %%
len(wordList)
# Out:
# 100481

# %%
wordList
# Out:
# ['breaking',
#  'abortion',
#  'pill',
#  'made',
#  'widely',
#  'available',
#  'new',
#  'fda',
#  'rules',
#  'allowing',
#  'brick-and-mortar',
#  'pharmacies',
#  'dispense',
#  'drug',
#  'first',
#  'time',
#  'https',
#  '//t.co/3x0w7d7yw3',
#  'rivian',
#  'fell',
#  'short',
#  '25,000-vehicle',
#  'production',
#  'target',
#  '2022',
#  'capping',
#  'challenging',
#  'year',
#  'electric-truck',
#  'startup',
#  '//t.co/cgkfg0tn0d',
#  '🎧',
#  'listen',
#  'today',
#  "'s",
#  'episode',
#  'journal',
#  'podcast',
#  'reporters',
#  'unpack',
#  'mixed',
#  'economic',
#  'picture',
#  'inflation',
#  'soared',
#  'labor',
#  'market',
#  'boomed',
#  'might',
#  'change',
#  '2023',
#  '//t.co/aj0u69imgu',
#  'damar',
#  'hamlin',
#  '‘',
#  'charitable',
#  'toy',
#  'drive',
#  'raised',
#  '4.8',
#  'million',
#  'less',
#  'day',
#  'since',
#  'buffalo',
#  'bills',
#  'player',
#  'collapsed',
#  'middle',
#  'monday',
#  'night',
#  '’',
#  'game',
# ...
