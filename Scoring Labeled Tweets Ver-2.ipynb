# %%
def bull_word_score(text):
    very_bullish = ['booming', 'soaring', 'thriving', 'record-breaking', 
                    'explosive','breakout', 'surging', 'high','bull', 
                    'unstoppable', 'skyrocketing', 'phenomenal', 'exponential',
                    'rocketing','robust','rampant','thriving','flourishing','strong',
                    'great', 'boon','bullish','opportunity','favorable',
                    'strong','gains','optimistic','soaring', 'skyrocketing', 'surging', 'outperforming',
                    'thriving', 'flourishing', 'booming', 'exploding', 'remarkable',
                    'exponential', 'impressive', 'accelerating', 'rallying', 'unstoppable',
                    'climbing', 'phenomenal', 'gaining', 'exceptional', 'momentum',
                    'breakthrough', 'expansion', 'uptrend', 'prolific', 'captivating',
                    'energized', 'bull-run', 'optimistic', 'sustained', 'pioneering',
                    'groundbreaking', 'upturn', 'lucrative', 'growth', 'escalating',
                    'leaping', 'earnings', 'profitable', 'appreciating', 'advancing',
                    'outpacing', 'upbeat', 'encouraging', 'favorable', 'upside',
                    'solid', 'emerging', 'rising', 'strengthening', 'progressive', 'revitalizing', 'dovish', 'pivot', 'up']

    bullish = ['strong','promising','encouraging','momentum','positive',
               'advancing','rising','growing','healthy','solid','steady',
               'improving','rallying','ascending','bright','favorable',
               'progressive', 'uptick','encouraging','rally',
               'upswing','expansion','rebounding','positive', 'improving', 'gains', 'increase', 'growth',
               'recovery', 'rally', 'rebound', 'incline', 'advance', 'progress',
               'upward', 'optimism', 'supportive', 'constructive', 'momentum', 'confidence',
               'stabilizing', 'opportunity', 'enhanced', 'rising', 'earnings', 
               'inflow', 'investment', 'strengthened', 'upturn', 'expansion', 'demand',
               'favorable', 'performance', 'resilient', 'sustainable', 'higher', 'profit',
               'development', 'returns', 'acceleration', 'growth', 'accumulation',
               'appreciation', 'upswing', 'boost', 'potential', 'success', 'bull-market',
               'outperformance', 'long', 'rallying', 'picking-up', 'ascending', 'easing', 'ease',
               'pause', 'bullish', 'beat', 'calls', 'add', 'peace', 'sound', 'resilient', 'uptrend', 'overbought', 'deal']

    bull_score = 0
    text_words = text.lower().split()
    for word in text_words:
        if word in very_bullish:
            bull_score += 2
        if word in bullish:
            bull_score += 1
    return bull_score

# %%
def bear_word_score(text):
    bearish = ['weak','downturn','declining','pessimistic','sinking','stagnant',
                'uncertain','sluggish','retreating','falling','negative','soft',
                'waning','deteriorating','cautious','shaky','fragile','unstable',
                'unsustainable','tepid','negative','bearish',
                'correction','sell','decline','contraction','underperforming',
                'decline', 'decrease', 'downturn', 'slump', 'drop',
                'downward', 'losses', 'weakness', 'slowdown', 'negative', 'lower',
                'correction', 'retreat', 'pessimism', 'contracting', 'underperforming',
                'sell-off', 'falling', 'stagnant', 'cautious', 'reducing', 'deteriorating',
                'erosion', 'tumble', 'pressured', 'devaluation', 'headwinds', 'bear-market',
                'uncertainty', 'downgrade', 'struggling', 'volatility', 'risky',
                'fluctuating', 'hesitant', 'reversal', 'worsening', 'vulnerable',
                'hindered', 'disappointing', 'underwhelming', 'waning', 'loss',
                'slide', 'turbulence', 'contraction', 'short', 'weakening', 'recessionary', 
                'tighten', 'tight', 'tightening', 'recession', 'bearish', 'missed', 'miss', 'puts',
                'inflation', 'cut', 'risks', 'tensions', 'war', 'panic', 'debt', 'fail', 'downtrend', 
                'loss', 'lost', 'oversold', 'sanction', 'sanctions']

    very_bearish = ['crashing','collapsing','plummeting','meltdown','panic',
                    'freefall','bottoming','disaster','catastrophe',
                    'desperate','failing','terrible','devastating','drastic','grim',
                    'bleak','gloomy','abysmal','meltdown','collapse','recession',
                    'crash','black','selling','bloodbath','crisis','depression',
                    'collapsing', 'plummeting', 'crashing', 'meltdown', 'freefall',
                    'devastating', 'disastrous', 'crisis', 'nosedive', 'steep-decrease',
                    'severe-downturn', 'dire', 'bleak', 'catastrophic', 'panicking',
                    'despair', 'bankruptcy', 'insolvency', 'liquidation', 'default',
                    'depressed', 'depletion', 'failing', 'massive-loss', 'implosion',
                    'bear-raid', 'alarm', 'shattered', 'destruction',
                    'abrupt', 'hopeless', 'widespread-fall', 'debacle', 'rout',
                    'steep-fall', 'undermined', 'unraveling', 'ruin', 'disintegration',
                    'downfall', 'excessive-risk', 'drastic', 'panic-selling', 'crisis-driven',
                    'eviscerating', 'debilitating', 'cataclysmic', 'dismal', 'economic-collapse',
                    'hawkish', 'depression', 'hike', 'default', 'down']
    

    bear_score = 0
    text_words = text.lower().split()
    for word in text_words:
        if word in very_bearish:
            bear_score += 2
        if word in bearish:
            bear_score += 1
    return bear_score

# %%
import pandas as pd
df = pd.read_csv("LabeledTweets.csv")
df = df.drop(['Unnamed: 1'],axis=1)
df['Bull Score'] = df['Content'].apply(lambda x: bull_word_score(x))
df['Bear Score'] = df['Content'].apply(lambda x: bear_word_score(x))

# %%
df['Score'] = df['Bull Score'] - df['Bear Score']

# %%
df
# Out:
#              Date                                            Content  \
# 0      2023-01-03  Breaking: An abortion pill will be made more w...
# 1      2023-01-03  Rivian fell short of its 25,000-vehicle produc...
# 2      2023-01-03  🎧  Listen: In today's episode of The Journal p...
# 3      2023-01-03  Damar Hamlin‘s charitable toy drive has raised...
# 4      2023-01-03  Federal prosecutors have charged two men in th...
# ...           ...                                                ...
# 98416  2023-04-20  Transgender Athlete Barred from Australian Wom...
# 98417  2023-04-20  Trump's Palm Beach Mansion Next To Mar-A-Lago ...
# 98418  2023-04-20  Disney announces groundbreaking for affordable...
# 98419  2023-04-20  Fed to deliver 25-basis-point hike in May, sta...
# 98420  2023-04-20  Hollywood is facing its first potential writer...
#
#            Username Target  Bull Score  Bear Score  Score
# 0               WSJ   Down           0           0      0
# ...

# %%
df = df.sort_values(['Score'])
Scores = list(df['Score'])

# %%
df
# Out:
#              Date                                            Content  \
# 40342  2023-03-10  Is Fed Chair Powell “willing to take a recessi...
# 63222  2023-03-24  JPMORGAN SHARES DOWN 1.1%, MORGAN STANLEY DOWN...
# 98010  2023-04-19  SHARES OF CRYPTO COS DOWN AFTER BITCOIN NEARS ...
# 63442  2023-03-24  ⚠️  COINBASE GLOBAL SHARES DOWN 3.6%, BITFARMS...
# 90808  2023-04-13  FOMC: "The Fed staff now expects the economy t...
# ...           ...                                                ...
# 1379   2023-01-05  FED'S BULLARD: JOB MARKET CAN REMAIN RESILIENT...
# 89906  2023-04-13  SHARES OF CRYPTO STOCKS UP AFTER BITCOIN CLIMB...
# 77623  2023-04-04  Soaring technology stocks run the risk of rall...
# 28858  2023-03-02  • Stocks open mixed this morning with sectors ...
# 85339  2023-04-11  IMF FORECASTS 2023 U.S. GROWTH AT 1.6% VS 1.4%...
#
#            Username Target  Bull Score  Bear Score  Score
# 40342  YahooFinance   Down           0          12    -12
# ...

# %%
df.to_csv('SeperateLabledScoredTweets.csv')

# %%
import statistics
std = statistics.stdev(Scores)
mean = statistics.mean(Scores)

print('Statics of df:')
print(f"Median: {statistics.median(Scores)}")
print(f"Mode: {statistics.mode(Scores)}")
print(f"Mean: {mean}")
print(f"Std: {std}")
print(f'Max: {max(Scores)}')
print(f'Min: {min(Scores)}')
# Out:
# Statics of df:
# Median: 0
# Mode: 0
# Mean: 0.058544416333912476
# Std: 1.224324468063845
# Max: 15
# Min: -12

# %%
import numpy as np
import matplotlib.pyplot as plt

plt.hist(Scores, bins=range(min(Scores),max(Scores),1), density=True, alpha=0.7, color='blue',edgecolor='black')
plt.axvline(mean, color='red', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(mean + std, color='green', linestyle='dashed', linewidth=1, label='1 Std')
plt.axvline(mean - std, color='green', linestyle='dashed', linewidth=1)
plt.xlabel('Tweet "Score"')
plt.ylabel('Percentage of total Tweets')
plt.title('Distrabution of Scores accross all Tweets')
plt.legend()
plt.show()

# add colors to the tweets in particular (save for EDA)
